# %%
from AgentBasedModel.params_calibration.utils_calibration import *

# %%
file_10s = "ethusdt_10s_300days.csv"
file_5m = "ethusdt_5m_1year.csv"

prices_10s = get_prices(file_10s)
params = pipeline(prices_10s)
plot_autocorr(params)
# Out:
# ETHUSDT stylized facts
# ========================================================================
#           metric               value
#     mean_on_ret2   0.000003 (0.000%)
#      std_on_ret2   0.002170 (0.217%)
#      min_on_ret2 -0.061959 (-6.196%)
#      max_on_ret2   0.052905 (5.290%)
#  skewness_on_ret           -0.148065
# kurtosis_on_ret2           28.178297
#
# Autocorrelation by lag
# ------------------------------------------------------------------------
#  lag  autocorr_ret  autocorr_abs_ret
#    0        1.0000            1.0000
#    1        0.0096            0.3605
#    2        0.0031            0.3254
#    3       -0.0009            0.3096
#    4       -0.0049            0.2952
#    5       -0.0027            0.2900
#    6        0.0007            0.2938
#    7       -0.0041            0.2799
#    8        0.0041            0.2745
#    9       -0.0023            0.2691
#   10       -0.0057            0.2663
#   11       -0.0019            0.2631
#   12        0.0043            0.2707
#   13       -0.0008            0.2578
#   14       -0.0033            0.2556
#   15        0.0001            0.2566
#   16       -0.0012            0.2539
#   17       -0.0010            0.2529
#   18        0.0044            0.2605
#   19       -0.0015            0.2489
#   20       -0.0004            0.2456
# ========================================================================
